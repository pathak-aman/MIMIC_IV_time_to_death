# %%
import pandas as pd
from pathlib import Path
from loguru import logger
import sys


# Set pandas columns width to 100
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.max_columns', 100)

# %%
RAW_DATA_DIR = '../data/raw'
csv_paths = Path(RAW_DATA_DIR)
all_csv_files = list(csv_paths.rglob('*.csv'))
# Read all n_rows = 5 of CSV files into a list of DataFrames
n_rows = 50
dfs = {}
for csv_file in all_csv_files:
    try:
        df = pd.read_csv(csv_file, nrows=n_rows)
        dfs[csv_file.stem] = df
    except Exception as e:
        logger.error(f"Error reading {csv_file}: {e}")

# %%
s = dfs["labevents"].merge(dfs["d_labitems"], how="left", left_on="itemid", right_on="itemid")
# Print the first 5 rows of each DataFrame
s.head()
# Out:
#    labevent_id  subject_id  hadm_id  specimen_id  itemid            charttime  \
# 0            1    10000032      NaN     45421181   51237  2180-03-23 11:51:00
# 1            2    10000032      NaN     45421181   51274  2180-03-23 11:51:00
# 2            3    10000032      NaN     52958335   50853  2180-03-23 11:51:00
# 3            4    10000032      NaN     52958335   50861  2180-03-23 11:51:00
# 4            5    10000032      NaN     52958335   50862  2180-03-23 11:51:00
#
#              storetime value  valuenum valueuom  ref_range_lower  \
# 0  2180-03-23 15:15:00   1.4       1.4      NaN              0.9
# 1  2180-03-23 15:15:00   ___      15.1      sec              9.4
# 2  2180-03-25 11:06:00   ___      15.0    ng/mL             30.0
# 3  2180-03-23 16:40:00   102     102.0     IU/L              0.0
# 4  2180-03-23 16:40:00   3.3       3.3     g/dL              3.5
#
#    ref_range_upper      flag priority  \
# 0              1.1  abnormal  ROUTINE
# 1             12.5  abnormal  ROUTINE
# 2             60.0  abnormal  ROUTINE
# 3             40.0  abnormal  ROUTINE
# 4              5.2  abnormal  ROUTINE
#
#                                                     comments label fluid  \
# 0                                                        NaN   NaN   NaN
# 1                                                  VERIFIED.   NaN   NaN
# 2  NEW ASSAY IN USE ___: DETECTS D2 AND D3 25-OH ACCURATELY.   NaN   NaN
# 3                                                        NaN   NaN   NaN
# 4                                                        NaN   NaN   NaN
#
#   category
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
dfs["d_icd_procedures"].head()
# Out:
#   icd_code  icd_version                                             long_title
# 0     0001            9     Therapeutic ultrasound of vessels of head and neck
# 1     0002            9                        Therapeutic ultrasound of heart
# 2     0003            9  Therapeutic ultrasound of peripheral vascular vessels
# 3     0009            9                           Other therapeutic ultrasound
# 4      001           10      Central Nervous System and Cranial Nerves, Bypass

# %%
dfs["d_labitems"].head()
# Out:
#    itemid                                label  fluid   category
# 0   50801           Alveolar-arterial Gradient  Blood  Blood Gas
# 1   50802                          Base Excess  Blood  Blood Gas
# 2   50803  Calculated Bicarbonate, Whole Blood  Blood  Blood Gas
# 3   50804                 Calculated Total CO2  Blood  Blood Gas
# 4   50805                    Carboxyhemoglobin  Blood  Blood Gas

# %%
dfs["labevents"].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   labevent_id      50 non-null     int64
#  1   subject_id       50 non-null     int64
#  2   hadm_id          0 non-null      float64
#  3   specimen_id      50 non-null     int64
#  4   itemid           50 non-null     int64
#  5   charttime        50 non-null     object
#  6   storetime        50 non-null     object
#  7   value            35 non-null     object
#  8   valuenum         34 non-null     float64
#  9   valueuom         38 non-null     object
#  10  ref_range_lower  33 non-null     float64
#  11  ref_range_upper  33 non-null     float64
#  12  flag             13 non-null     object
#  13  priority         50 non-null     object
#  14  comments         21 non-null     object
# dtypes: float64(4), int64(4), object(7)
# memory usage: 6.0+ KB

# %%
dfs["d_labitems"].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   itemid    50 non-null     int64
#  1   label     50 non-null     object
#  2   fluid     50 non-null     object
#  3   category  50 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.7+ KB

# %%
all_csv_files
# Out:
# [PosixPath('../data/raw/mimiciv/2.1/hosp/admissions.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/diagnoses_icd.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/drgcodes.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/d_hcpcs.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/d_icd_diagnoses.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/d_icd_procedures.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/d_labitems.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/emar.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/emar_detail.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/hcpcsevents.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/labevents.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/microbiologyevents.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/omr.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/patients.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/pharmacy.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/poe.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/poe_detail.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/prescriptions.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/procedures_icd.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/services.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/hosp/transfers.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/icu/chartevents.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/icu/datetimeevents.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/icu/d_items.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/icu/icustays.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/icu/ingredientevents.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/icu/inputevents.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/icu/outputevents.csv'),
#  PosixPath('../data/raw/mimiciv/2.1/icu/procedureevents.csv')]

# %%
diagnosis = pd.read_csv('../data/raw/mimiciv/2.1/hosp/d_icd_diagnoses.csv')
diagnosis.head()
# Out:
#   icd_code  icd_version                             long_title
# 0     0010            9         Cholera due to vibrio cholerae
# 1     0011            9  Cholera due to vibrio cholerae el tor
# 2     0019            9                   Cholera, unspecified
# 3     0020            9                          Typhoid fever
# 4     0021            9                    Paratyphoid fever A

# %%
CHF_CODES = ['428', 'I50']  # ICD-9 code for Congestive heart failure (use prefix matches)
DIABETES_CODES = ['250', 'E08']
CKD_CODES = ['585', 'N18']
COPD_CODES = ['491', '492', '496', 'J44']
CANCER_CODES = ['140', '141', '142', '143', '144', '145', '146', '147', '148', '149', 'C00', 'C']  # example ranges
LIVER_DISEASE_CODES = ['571', 'K7']
MI_CODES = ['410', "I21"]
STROKE_CODES = ['434', '436', 'I630']
SEPSIS_CODES = ['99591', '99592', 'A400','A41']  # example, ICD-9 codes for sepsis
AKI_CODES = ['584',"N17"]

# %%
ICD_CONDITION_MAP = {
    "CHF_ICD_CODES" : ['428', 'I50'],
    "DIABETES_ICD_CODES" : ['250', 'E08'],
    "CKD_ICD_CODES" : ['585', 'N18'],
    "CANCER_ICD_CODES" : ['140', '141', '142', '143', '144', '145', '146', '147', '148', '149','C00', 'C'],
    "COPD_ICD_CODES" : ['491', '492', '496', 'J44'],
    "LIVER_DISEASE_ICD_CODES" : ['571', 'K7'],
    "MI_ICD_CODES" : ['410', "I21"],
    "STROKE_ICD_CODES" : ['434', '436', 'I630'],
    "SEPSIS_ICD_CODES" : ['99591', '99592', 'A400','A41'],
    "AKI_ICD_CODES" : ['584',"N17"]
}

# %%
diagnosis[diagnosis["icd_code"].str.startswith(tuple(AKI_CODES))]
# Out:
#       icd_code  icd_version  \
# 5982      5845            9
# 5983      5846            9
# 5984      5847            9
# 5985      5848            9
# 5986      5849            9
# 37307      N17           10
# 37308     N170           10
# 37309     N171           10
# 37310     N172           10
# 37311     N178           10
# 37312     N179           10
#
#                                                                      long_title
# 5982                       Acute kidney failure with lesion of tubular necrosis
# 5983                Acute kidney failure with lesion of renal cortical necrosis
# 5984   Acute kidney failure with lesion of renal medullary [papillary] necrosis
# 5985    Acute kidney failure with other specified pathological lesion in kidney
# 5986                                          Acute kidney failure, unspecified
# 37307                                                      Acute kidney failure
# 37308                                Acute kidney failure with tubular necrosis
# 37309                         Acute kidney failure with acute cortical necrosis
# 37310                              Acute kidney failure with medullary necrosis
# 37311                                                Other acute kidney failure
# 37312                                         Acute kidney failure, unspecified

# %%
diagnosis[(diagnosis["long_title"].str.contains("Acute kidney failure", case=False)) & (diagnosis["icd_version"] == 10)].to_dict("records")
# Out:
# [{'icd_code': 'N17', 'icd_version': 10, 'long_title': 'Acute kidney failure'},
#  {'icd_code': 'N170',
#   'icd_version': 10,
#   'long_title': 'Acute kidney failure with tubular necrosis'},
#  {'icd_code': 'N171',
#   'icd_version': 10,
#   'long_title': 'Acute kidney failure with acute cortical necrosis'},
#  {'icd_code': 'N172',
#   'icd_version': 10,
#   'long_title': 'Acute kidney failure with medullary necrosis'},
#  {'icd_code': 'N178',
#   'icd_version': 10,
#   'long_title': 'Other acute kidney failure'},
#  {'icd_code': 'N179',
#   'icd_version': 10,
#   'long_title': 'Acute kidney failure, unspecified'},
#  {'icd_code': 'O904',
#   'icd_version': 10,
#   'long_title': 'Postpartum acute kidney failure'}]

# %%
diagnosis = pd.read_csv('../data/raw/mimiciv/2.1/hosp/d_icd_diagnoses.csv')
diagnosis.head()

# %%
procedure_df = pd.read_csv('../data/raw/mimiciv/2.1/hosp/d_icd_procedures.csv')
procedure_df.head()
# Out:
#   icd_code  icd_version                                             long_title
# 0     0001            9     Therapeutic ultrasound of vessels of head and neck
# 1     0002            9                        Therapeutic ultrasound of heart
# 2     0003            9  Therapeutic ultrasound of peripheral vascular vessels
# 3     0009            9                           Other therapeutic ultrasound
# 4      001           10      Central Nervous System and Cranial Nerves, Bypass

# %%
PROCEDURE_ICD_MAP = {
    'major_surgery': ['361', '352', '815', '8151', 'Y8'],  # e.g., valve surgery, CABG, resections
    'mech_vent': ['967'],  # mechanical ventilation
    'dialysis': ['3995', '5498'],  # dialysis codes
    'biopsy': ['9021', '9022', '9023'],  # biopsy
}

# %%
procedure_df[procedure_df["icd_code"].str.startswith(tuple(PROCEDURE_ICD_MAP["major_surgery"]))]
# Out:
#       icd_code  icd_version  \
# 73153     3520            9
# 73154     3521            9
# 73155     3522            9
# 73156     3523            9
# 73157     3524            9
# 73158     3525            9
# 73159     3526            9
# 73160     3527            9
# 73161     3528            9
# 73202     3610            9
# 73203     3611            9
# 73204     3612            9
# 73205     3613            9
# 73206     3614            9
# 73207     3615            9
# 73208     3616            9
# 73209     3617            9
# 73210     3619            9
# 76716     8151            9
# 76717     8152            9
# 76718     8153            9
# 76719     8154            9
# 76720     8155            9
# 76721     8156            9
# 76722     8157            9
# 76723     8159            9
#
#                                                                        long_title
# 73153                       Open and other replacement of unspecified heart valve
# 73154                Open and other replacement of aortic valve with tissue graft
# 73155                                  Open and other replacement of aortic valve
# 73156                Open and other replacement of mitral valve with tissue graft
# 73157                                  Open and other replacement of mitral valve
# 73158             Open and other replacement of pulmonary valve with tissue graft
# 73159                               Open and other replacement of pulmonary valve
# 73160             Open and other replacement of tricuspid valve with tissue graft
# 73161                               Open and other replacement of tricuspid valve
# 73202   Aortocoronary bypass for heart revascularization, not otherwise specified
# 73203                               (Aorto)coronary bypass of one coronary artery
# 73204                             (Aorto)coronary bypass of two coronary arteries
# 73205                           (Aorto)coronary bypass of three coronary arteries
# 73206                    (Aorto)coronary bypass of four or more coronary arteries
# 73207                              Single internal mammary-coronary artery bypass
# 73208                              Double internal mammary-coronary artery bypass
# 73209                                            Abdominal-coronary artery bypass
# 73210                        Other bypass anastomosis for heart revascularization
# 76716                                                       Total hip replacement
# 76717                                                     Partial hip replacement
# 76718                        Revision of hip replacement, not otherwise specified
# 76719                                                      Total knee replacement
# 76720                       Revision of knee replacement, not otherwise specified
# 76721                                                     Total ankle replacement
# 76722                                        Replacement of joint of foot and toe
# 76723  Revision of joint replacement of lower extremity, not elsewhere classified

# %%
procedure_df[(procedure_df["long_title"].str.contains("replacement", case=False)) & (procedure_df["icd_version"] == 10)].to_dict("records")
# Out:
# [{'icd_code': '00R',
#   'icd_version': 10,
#   'long_title': 'Central Nervous System and Cranial Nerves, Replacement'},
#  {'icd_code': '00R107Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cerebral Meninges with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00R10JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cerebral Meninges with Synthetic Substitute, Open Approach'},
#  {'icd_code': '00R10KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cerebral Meninges with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00R147Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cerebral Meninges with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00R14JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cerebral Meninges with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00R14KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cerebral Meninges with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00R207Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Dura Mater with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00R20JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Dura Mater with Synthetic Substitute, Open Approach'},
#  {'icd_code': '00R20KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Dura Mater with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00R247Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Dura Mater with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00R24JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Dura Mater with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00R24KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Dura Mater with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00R607Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cerebral Ventricle with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00R60JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cerebral Ventricle with Synthetic Substitute, Open Approach'},
#  {'icd_code': '00R60KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cerebral Ventricle with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00R647Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cerebral Ventricle with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00R64JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cerebral Ventricle with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00R64KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cerebral Ventricle with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RF07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Olfactory Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RF0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Olfactory Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '00RF0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Olfactory Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RF47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Olfactory Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RF4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Olfactory Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RF4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Olfactory Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RG07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Optic Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RG0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Optic Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '00RG0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Optic Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RG47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Optic Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RG4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Optic Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RG4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Optic Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RH07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Oculomotor Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RH0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Oculomotor Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '00RH0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Oculomotor Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RH47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Oculomotor Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RH4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Oculomotor Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RH4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Oculomotor Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RJ07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Trochlear Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RJ0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Trochlear Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '00RJ0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Trochlear Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RJ47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Trochlear Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RJ4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Trochlear Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RJ4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Trochlear Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RK07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Trigeminal Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RK0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Trigeminal Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '00RK0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Trigeminal Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RK47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Trigeminal Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RK4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Trigeminal Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RK4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Trigeminal Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RL07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Abducens Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RL0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Abducens Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '00RL0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Abducens Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RL47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Abducens Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RL4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Abducens Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RL4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Abducens Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RM07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Facial Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RM0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Facial Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '00RM0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Facial Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RM47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Facial Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RM4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Facial Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RM4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Facial Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RN07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Acoustic Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RN0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Acoustic Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '00RN0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Acoustic Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RN47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Acoustic Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RN4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Acoustic Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RN4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Acoustic Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RP07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Glossopharyngeal Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RP0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Glossopharyngeal Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '00RP0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Glossopharyngeal Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RP47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Glossopharyngeal Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RP4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Glossopharyngeal Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RP4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Glossopharyngeal Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RQ07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Vagus Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RQ0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Vagus Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '00RQ0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Vagus Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RQ47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Vagus Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RQ4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Vagus Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RQ4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Vagus Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RR07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Accessory Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RR0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Accessory Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '00RR0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Accessory Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RR47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Accessory Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RR4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Accessory Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RR4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Accessory Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RS07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Hypoglossal Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RS0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Hypoglossal Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '00RS0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Hypoglossal Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RS47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Hypoglossal Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RS4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Hypoglossal Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RS4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Hypoglossal Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RT07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Spinal Meninges with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RT0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Spinal Meninges with Synthetic Substitute, Open Approach'},
#  {'icd_code': '00RT0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Spinal Meninges with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '00RT47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Spinal Meninges with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RT4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Spinal Meninges with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '00RT4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Spinal Meninges with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R',
#   'icd_version': 10,
#   'long_title': 'Peripheral Nervous System, Replacement'},
#  {'icd_code': '01R107Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cervical Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01R10JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cervical Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '01R10KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cervical Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01R147Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cervical Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R14JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cervical Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R14KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Cervical Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R207Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Phrenic Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01R20JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Phrenic Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '01R20KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Phrenic Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01R247Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Phrenic Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R24JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Phrenic Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R24KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Phrenic Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R407Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Ulnar Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01R40JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Ulnar Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '01R40KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Ulnar Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01R447Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Ulnar Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R44JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Ulnar Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R44KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Ulnar Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R507Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Median Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01R50JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Median Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '01R50KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Median Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01R547Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Median Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R54JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Median Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R54KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Median Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R607Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Radial Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01R60JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Radial Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '01R60KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Radial Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01R647Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Radial Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R64JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Radial Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R64KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Radial Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R807Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Thoracic Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01R80JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Thoracic Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '01R80KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Thoracic Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01R847Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Thoracic Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R84JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Thoracic Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01R84KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Thoracic Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RB07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Lumbar Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01RB0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Lumbar Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '01RB0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Lumbar Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01RB47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Lumbar Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RB4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Lumbar Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RB4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Lumbar Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RC07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pudendal Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01RC0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pudendal Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '01RC0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pudendal Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01RC47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pudendal Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RC4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pudendal Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RC4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pudendal Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RD07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Femoral Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01RD0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Femoral Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '01RD0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Femoral Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01RD47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Femoral Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RD4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Femoral Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RD4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Femoral Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RF07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Sciatic Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01RF0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Sciatic Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '01RF0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Sciatic Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01RF47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Sciatic Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RF4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Sciatic Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RF4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Sciatic Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RG07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tibial Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01RG0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tibial Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '01RG0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tibial Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01RG47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tibial Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RG4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tibial Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RG4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tibial Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RH07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Peroneal Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01RH0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Peroneal Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '01RH0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Peroneal Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01RH47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Peroneal Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RH4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Peroneal Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RH4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Peroneal Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RR07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Sacral Nerve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01RR0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Sacral Nerve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '01RR0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Sacral Nerve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '01RR47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Sacral Nerve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RR4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Sacral Nerve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '01RR4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Sacral Nerve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02R',
#   'icd_version': 10,
#   'long_title': 'Heart and Great Vessels, Replacement'},
#  {'icd_code': '02R507Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Atrial Septum with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02R508Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Atrial Septum with Zooplastic Tissue, Open Approach'},
#  {'icd_code': '02R50JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Atrial Septum with Synthetic Substitute, Open Approach'},
#  {'icd_code': '02R50KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Atrial Septum with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02R547Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Atrial Septum with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02R548Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Atrial Septum with Zooplastic Tissue, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02R54JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Atrial Septum with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02R54KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Atrial Septum with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02R607Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Atrium with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02R608Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Atrium with Zooplastic Tissue, Open Approach'},
#  {'icd_code': '02R60JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Atrium with Synthetic Substitute, Open Approach'},
#  {'icd_code': '02R60KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Atrium with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02R647Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Atrium with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02R648Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Atrium with Zooplastic Tissue, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02R64JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Atrium with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02R64KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Atrium with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02R707Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Atrium with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02R708Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Atrium with Zooplastic Tissue, Open Approach'},
#  {'icd_code': '02R70JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Atrium with Synthetic Substitute, Open Approach'},
#  {'icd_code': '02R70KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Atrium with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02R747Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Atrium with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02R748Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Atrium with Zooplastic Tissue, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02R74JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Atrium with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02R74KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Atrium with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02R907Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Chordae Tendineae with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02R908Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Chordae Tendineae with Zooplastic Tissue, Open Approach'},
#  {'icd_code': '02R90JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Chordae Tendineae with Synthetic Substitute, Open Approach'},
#  {'icd_code': '02R90KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Chordae Tendineae with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02R947Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Chordae Tendineae with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02R948Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Chordae Tendineae with Zooplastic Tissue, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02R94JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Chordae Tendineae with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02R94KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Chordae Tendineae with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RD07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Papillary Muscle with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RD08Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Papillary Muscle with Zooplastic Tissue, Open Approach'},
#  {'icd_code': '02RD0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Papillary Muscle with Synthetic Substitute, Open Approach'},
#  {'icd_code': '02RD0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Papillary Muscle with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RD47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Papillary Muscle with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RD48Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Papillary Muscle with Zooplastic Tissue, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RD4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Papillary Muscle with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RD4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Papillary Muscle with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RF07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Aortic Valve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RF08Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Aortic Valve with Zooplastic Tissue, Open Approach'},
#  {'icd_code': '02RF0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Aortic Valve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '02RF0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Aortic Valve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RF37H',
#   'icd_version': 10,
#   'long_title': 'Replacement of Aortic Valve with Autologous Tissue Substitute, Transapical, Percutaneous Approach'},
#  {'icd_code': '02RF37Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Aortic Valve with Autologous Tissue Substitute, Percutaneous Approach'},
#  {'icd_code': '02RF38H',
#   'icd_version': 10,
#   'long_title': 'Replacement of Aortic Valve with Zooplastic Tissue, Transapical, Percutaneous Approach'},
#  {'icd_code': '02RF38Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Aortic Valve with Zooplastic Tissue, Percutaneous Approach'},
#  {'icd_code': '02RF3JH',
#   'icd_version': 10,
#   'long_title': 'Replacement of Aortic Valve with Synthetic Substitute, Transapical, Percutaneous Approach'},
#  {'icd_code': '02RF3JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Aortic Valve with Synthetic Substitute, Percutaneous Approach'},
#  {'icd_code': '02RF3KH',
#   'icd_version': 10,
#   'long_title': 'Replacement of Aortic Valve with Nonautologous Tissue Substitute, Transapical, Percutaneous Approach'},
#  {'icd_code': '02RF3KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Aortic Valve with Nonautologous Tissue Substitute, Percutaneous Approach'},
#  {'icd_code': '02RF47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Aortic Valve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RF48Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Aortic Valve with Zooplastic Tissue, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RF4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Aortic Valve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RF4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Aortic Valve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RG07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Mitral Valve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RG08Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Mitral Valve with Zooplastic Tissue, Open Approach'},
#  {'icd_code': '02RG0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Mitral Valve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '02RG0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Mitral Valve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RG37H',
#   'icd_version': 10,
#   'long_title': 'Replacement of Mitral Valve with Autologous Tissue Substitute, Transapical, Percutaneous Approach'},
#  {'icd_code': '02RG37Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Mitral Valve with Autologous Tissue Substitute, Percutaneous Approach'},
#  {'icd_code': '02RG38H',
#   'icd_version': 10,
#   'long_title': 'Replacement of Mitral Valve with Zooplastic Tissue, Transapical, Percutaneous Approach'},
#  {'icd_code': '02RG38Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Mitral Valve with Zooplastic Tissue, Percutaneous Approach'},
#  {'icd_code': '02RG3JH',
#   'icd_version': 10,
#   'long_title': 'Replacement of Mitral Valve with Synthetic Substitute, Transapical, Percutaneous Approach'},
#  {'icd_code': '02RG3JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Mitral Valve with Synthetic Substitute, Percutaneous Approach'},
#  {'icd_code': '02RG3KH',
#   'icd_version': 10,
#   'long_title': 'Replacement of Mitral Valve with Nonautologous Tissue Substitute, Transapical, Percutaneous Approach'},
#  {'icd_code': '02RG3KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Mitral Valve with Nonautologous Tissue Substitute, Percutaneous Approach'},
#  {'icd_code': '02RG47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Mitral Valve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RG48Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Mitral Valve with Zooplastic Tissue, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RG4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Mitral Valve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RG4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Mitral Valve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RH07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Valve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RH08Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Valve with Zooplastic Tissue, Open Approach'},
#  {'icd_code': '02RH0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Valve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '02RH0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Valve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RH37H',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Valve with Autologous Tissue Substitute, Transapical, Percutaneous Approach'},
#  {'icd_code': '02RH37Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Valve with Autologous Tissue Substitute, Percutaneous Approach'},
#  {'icd_code': '02RH38H',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Valve with Zooplastic Tissue, Transapical, Percutaneous Approach'},
#  {'icd_code': '02RH38Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Valve with Zooplastic Tissue, Percutaneous Approach'},
#  {'icd_code': '02RH3JH',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Valve with Synthetic Substitute, Transapical, Percutaneous Approach'},
#  {'icd_code': '02RH3JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Valve with Synthetic Substitute, Percutaneous Approach'},
#  {'icd_code': '02RH3KH',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Valve with Nonautologous Tissue Substitute, Transapical, Percutaneous Approach'},
#  {'icd_code': '02RH3KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Valve with Nonautologous Tissue Substitute, Percutaneous Approach'},
#  {'icd_code': '02RH47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Valve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RH48Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Valve with Zooplastic Tissue, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RH4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Valve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RH4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Valve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RJ07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tricuspid Valve with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RJ08Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tricuspid Valve with Zooplastic Tissue, Open Approach'},
#  {'icd_code': '02RJ0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tricuspid Valve with Synthetic Substitute, Open Approach'},
#  {'icd_code': '02RJ0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tricuspid Valve with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RJ37H',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tricuspid Valve with Autologous Tissue Substitute, Transapical, Percutaneous Approach'},
#  {'icd_code': '02RJ37Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tricuspid Valve with Autologous Tissue Substitute, Percutaneous Approach'},
#  {'icd_code': '02RJ38H',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tricuspid Valve with Zooplastic Tissue, Transapical, Percutaneous Approach'},
#  {'icd_code': '02RJ38Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tricuspid Valve with Zooplastic Tissue, Percutaneous Approach'},
#  {'icd_code': '02RJ3JH',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tricuspid Valve with Synthetic Substitute, Transapical, Percutaneous Approach'},
#  {'icd_code': '02RJ3JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tricuspid Valve with Synthetic Substitute, Percutaneous Approach'},
#  {'icd_code': '02RJ3KH',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tricuspid Valve with Nonautologous Tissue Substitute, Transapical, Percutaneous Approach'},
#  {'icd_code': '02RJ3KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tricuspid Valve with Nonautologous Tissue Substitute, Percutaneous Approach'},
#  {'icd_code': '02RJ47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tricuspid Valve with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RJ48Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tricuspid Valve with Zooplastic Tissue, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RJ4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tricuspid Valve with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RJ4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Tricuspid Valve with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RK07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Ventricle with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RK08Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Ventricle with Zooplastic Tissue, Open Approach'},
#  {'icd_code': '02RK0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Ventricle with Synthetic Substitute, Open Approach'},
#  {'icd_code': '02RK0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Ventricle with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RK47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Ventricle with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RK48Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Ventricle with Zooplastic Tissue, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RK4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Ventricle with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RK4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Ventricle with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RL07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Ventricle with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RL08Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Ventricle with Zooplastic Tissue, Open Approach'},
#  {'icd_code': '02RL0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Ventricle with Synthetic Substitute, Open Approach'},
#  {'icd_code': '02RL0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Ventricle with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RL47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Ventricle with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RL48Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Ventricle with Zooplastic Tissue, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RL4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Ventricle with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RL4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Ventricle with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RM07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Ventricular Septum with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RM08Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Ventricular Septum with Zooplastic Tissue, Open Approach'},
#  {'icd_code': '02RM0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Ventricular Septum with Synthetic Substitute, Open Approach'},
#  {'icd_code': '02RM0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Ventricular Septum with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RM47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Ventricular Septum with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RM48Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Ventricular Septum with Zooplastic Tissue, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RM4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Ventricular Septum with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RM4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Ventricular Septum with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RN07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pericardium with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RN08Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pericardium with Zooplastic Tissue, Open Approach'},
#  {'icd_code': '02RN0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pericardium with Synthetic Substitute, Open Approach'},
#  {'icd_code': '02RN0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pericardium with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RN47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pericardium with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RN48Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pericardium with Zooplastic Tissue, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RN4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pericardium with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RN4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pericardium with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '02RP07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Trunk with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '02RP08Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Trunk with Zooplastic Tissue, Open Approach'},
#  {'icd_code': '02RP0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Pulmonary Trunk with Synthetic Substitute, Open Approach'},
#  {'icd_code': '02RP0KZ',
#   'icd_version': 10,
# ...
#   'long_title': 'Replacement of Upper Vein with Synthetic Substitute, Open Approach'},
#  {'icd_code': '05RY0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Upper Vein with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '05RY47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Upper Vein with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '05RY4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Upper Vein with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '05RY4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Upper Vein with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R',
#   'icd_version': 10,
#   'long_title': 'Lower Veins, Replacement'},
#  {'icd_code': '06R007Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Inferior Vena Cava with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R00JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Inferior Vena Cava with Synthetic Substitute, Open Approach'},
#  {'icd_code': '06R00KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Inferior Vena Cava with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R047Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Inferior Vena Cava with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R04JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Inferior Vena Cava with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R04KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Inferior Vena Cava with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R107Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Splenic Vein with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R10JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Splenic Vein with Synthetic Substitute, Open Approach'},
#  {'icd_code': '06R10KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Splenic Vein with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R147Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Splenic Vein with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R14JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Splenic Vein with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R14KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Splenic Vein with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R207Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Gastric Vein with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R20JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Gastric Vein with Synthetic Substitute, Open Approach'},
#  {'icd_code': '06R20KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Gastric Vein with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R247Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Gastric Vein with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R24JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Gastric Vein with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R24KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Gastric Vein with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R307Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Esophageal Vein with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R30JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Esophageal Vein with Synthetic Substitute, Open Approach'},
#  {'icd_code': '06R30KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Esophageal Vein with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R347Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Esophageal Vein with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R34JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Esophageal Vein with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R34KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Esophageal Vein with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R407Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Hepatic Vein with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R40JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Hepatic Vein with Synthetic Substitute, Open Approach'},
#  {'icd_code': '06R40KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Hepatic Vein with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R447Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Hepatic Vein with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R44JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Hepatic Vein with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R44KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Hepatic Vein with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R507Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Superior Mesenteric Vein with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R50JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Superior Mesenteric Vein with Synthetic Substitute, Open Approach'},
#  {'icd_code': '06R50KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Superior Mesenteric Vein with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R547Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Superior Mesenteric Vein with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R54JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Superior Mesenteric Vein with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R54KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Superior Mesenteric Vein with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R607Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Inferior Mesenteric Vein with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R60JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Inferior Mesenteric Vein with Synthetic Substitute, Open Approach'},
#  {'icd_code': '06R60KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Inferior Mesenteric Vein with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R647Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Inferior Mesenteric Vein with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R64JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Inferior Mesenteric Vein with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R64KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Inferior Mesenteric Vein with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R707Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Colic Vein with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R70JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Colic Vein with Synthetic Substitute, Open Approach'},
#  {'icd_code': '06R70KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Colic Vein with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R747Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Colic Vein with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R74JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Colic Vein with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R74KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Colic Vein with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R807Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Portal Vein with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R80JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Portal Vein with Synthetic Substitute, Open Approach'},
#  {'icd_code': '06R80KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Portal Vein with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R847Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Portal Vein with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R84JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Portal Vein with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R84KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Portal Vein with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R907Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Renal Vein with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R90JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Renal Vein with Synthetic Substitute, Open Approach'},
#  {'icd_code': '06R90KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Renal Vein with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06R947Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Renal Vein with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R94JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Renal Vein with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06R94KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Renal Vein with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RB07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Renal Vein with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06RB0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Renal Vein with Synthetic Substitute, Open Approach'},
#  {'icd_code': '06RB0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Renal Vein with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06RB47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Renal Vein with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RB4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Renal Vein with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RB4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Renal Vein with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RC07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Common Iliac Vein with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06RC0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Common Iliac Vein with Synthetic Substitute, Open Approach'},
#  {'icd_code': '06RC0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Common Iliac Vein with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06RC47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Common Iliac Vein with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RC4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Common Iliac Vein with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RC4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Common Iliac Vein with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RD07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Common Iliac Vein with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06RD0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Common Iliac Vein with Synthetic Substitute, Open Approach'},
#  {'icd_code': '06RD0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Common Iliac Vein with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06RD47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Common Iliac Vein with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RD4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Common Iliac Vein with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RD4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Common Iliac Vein with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RF07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right External Iliac Vein with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06RF0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right External Iliac Vein with Synthetic Substitute, Open Approach'},
#  {'icd_code': '06RF0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right External Iliac Vein with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06RF47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right External Iliac Vein with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RF4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right External Iliac Vein with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RF4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right External Iliac Vein with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RG07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left External Iliac Vein with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06RG0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left External Iliac Vein with Synthetic Substitute, Open Approach'},
#  {'icd_code': '06RG0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left External Iliac Vein with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06RG47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left External Iliac Vein with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RG4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left External Iliac Vein with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RG4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left External Iliac Vein with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RH07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Hypogastric Vein with Autologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06RH0JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Hypogastric Vein with Synthetic Substitute, Open Approach'},
#  {'icd_code': '06RH0KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Hypogastric Vein with Nonautologous Tissue Substitute, Open Approach'},
#  {'icd_code': '06RH47Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Hypogastric Vein with Autologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RH4JZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Hypogastric Vein with Synthetic Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RH4KZ',
#   'icd_version': 10,
#   'long_title': 'Replacement of Right Hypogastric Vein with Nonautologous Tissue Substitute, Percutaneous Endoscopic Approach'},
#  {'icd_code': '06RJ07Z',
#   'icd_version': 10,
#   'long_title': 'Replacement of Left Hypogastric Vein with Autologous Tissue Substitute, Open Approach'},
#  ...]
